# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, accuracy_score, roc_auc_score, confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from ast import literal_eval

# %%
path_to_dataset = r'C:\Users\roszs\1PyFolder\the-movies-dataset\movies_metadata_fixed.csv'
dataset = pd.read_csv(path_to_dataset)
dataset.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
dataset.shape
# Out:
# (45463, 24)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45463 non-null  float64
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45463 non-null  int64
#  16  runtime                45206 non-null  float64
#  17  spoken_languages       45463 non-null  object
#  18  status                 45382 non-null  object
#  19  tagline                20413 non-null  object
#  20  title                  45463 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45463 non-null  float64
#  23  vote_count             45463 non-null  int64
# dtypes: bool(2), float64(3), int64(4), object(15)
# memory usage: 7.7+ MB

# %%
literal_eval(dataset['genres'].iloc[0])
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
[i['name'] for i in literal_eval(dataset['genres'].iloc[0])]
# Out:
# ['Animation', 'Comedy', 'Family']

# %%
dataset['genres'] = dataset['genres'].fillna('[]')\
                                     .apply(literal_eval)\
                                     .apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
dataset.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
import functools
available_genres = functools.reduce(lambda x,y: set(x).union(set(y)), dataset.genres.tolist())
available_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %%
dataset['year'] = pd.to_datetime(dataset['release_date']).dt.year

# %%
def process_dataset(df):
    
    ok_rows = (dataset['vote_count'].notnull()) & (dataset['vote_average'].notnull())
    rank_dataset = dataset[ok_rows]
    
    usecols_ = ['title', 'year', 'vote_count', 'vote_average', 'genres']
    rank_dataset = dataset[usecols_]
    
    return rank_dataset

# %%
dataset  = process_dataset(dataset.copy())
dataset.head()
# Out:
#                          title    year  vote_count  vote_average  \
# 0                    Toy Story  1995.0        5415           7.7
# 1                      Jumanji  1995.0        2413           6.9
# 2             Grumpier Old Men  1995.0          92           6.5
# 3            Waiting to Exhale  1995.0          34           6.1
# 4  Father of the Bride Part II  1995.0         173           5.7
#
#                          genres
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45463 non-null  object
#  1   year          45379 non-null  float64
#  2   vote_count    45463 non-null  int64
#  3   vote_average  45463 non-null  float64
#  4   genres        45463 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
dataset.shape
# Out:
# (45463, 5)

# %%
def the_best_formula(x, Q, C):
    v = float(x['vote_count'])
    R = x['vote_average']
    return (v/(v+Q) * R) + (Q/(Q+v) * C)

# %%
def recommend_best(input_films, n_items):
    
    rank = input_films.copy()
    C = rank.vote_average.mean()
    Q = rank.vote_count.quantile(0.95)
    print("Minimum number of votes: {}. Average overall rating: {}".format(int(Q),C))
    rank['formula'] = rank.apply(lambda x: the_best_formula(x, Q, C), axis = 1)
    rank.sort_values('formula', ascending=False, inplace=True)
    
    return rank.head(n_items).reset_index(drop=True)

def recommend_by_genre(input_films, n_items, genres):
    
    rank = input_films.copy()
    C = rank.vote_average.mean()
    Q = rank.vote_count.quantile(0.95)
    print("Minimum number of votes: {}. Average overall rating: {}".format(int(Q),C))
    rank['formula'] = rank.apply(lambda x: the_best_formula(x, Q, C), axis = 1)
    rank.sort_values('formula', ascending=False, inplace=True)
    
    rank['contains_genre'] = [all( y in x for y in genres) for x in rank.genres]
    rank = rank[rank.contains_genre == True]
    rank.drop('contains_genre', axis =1, inplace = True)
    
    return rank.head(n_items).reset_index(drop = True)

def recommend_by_genre_and_year(input_films, n_items, min_votes, genres, not_older_than):
    
    rank = input_films.copy()
    C = rank.vote_average.mean()
    Q = rank.vote_count.quantile(0.95)
    print("Minimum number of votes: {}. Average overall rating: {}".format(int(Q),C))
    rank['formula'] = rank.apply(lambda x: the_best_formula(x, Q, C), axis = 1)
    rank.sort_values('formula', ascending = False, inplace  =True)
    
    rank['contains_genre'] = [all( y in x for y in genres) for x in rank.genres]
    rank = rank[rank.contains_genre == True]
    rank.drop('contains_genre', axis = 1, inplace = True)
    
    rank = rank[rank.year >= not_older_than]
    
    return rank.head(n_items).reset_index(drop=True)
    
recommend_by_genre_and_year(dataset, 15, 100, genres=['Drama'], not_older_than = 1970)
# Out:
# Minimum number of votes: 433. Average overall rating: 5.618217011635541
#                               title    year  vote_count  vote_average  \
# 0          The Shawshank Redemption  1994.0        8358           8.5
# 1                     The Godfather  1972.0        6024           8.5
# 2                   The Dark Knight  2008.0       12269           8.3
# 3                        Fight Club  1999.0        9678           8.3
# 4                      Forrest Gump  1994.0        8147           8.2
# 5                  Schindler's List  1993.0        4436           8.3
# 6                          Whiplash  2014.0        4376           8.3
# 7                 Life Is Beautiful  1997.0        3643           8.3
# 8                  The Intouchables  2011.0        5410           8.2
# 9                      Interstellar  2014.0       11187           8.1
# 10           The Godfather: Part II  1974.0        3418           8.3
# 11           Leon: The Professional  1994.0        4293           8.2
# 12  One Flew Over the Cuckoo's Nest  1975.0        3001           8.3
# 13                   The Green Mile  1999.0        4166           8.2
# 14                       GoodFellas  1990.0        3211           8.2
#
#                                  genres   formula
# 0                        [Drama, Crime]  8.357778
# 1                        [Drama, Crime]  8.306376
# 2      [Drama, Action, Crime, Thriller]  8.208397
# 3                               [Drama]  8.184925
# 4              [Comedy, Drama, Romance]  8.069450
# 5                 [Drama, History, War]  8.061058
# 6                               [Drama]  8.058077
# 7                       [Comedy, Drama]  8.014581
# 8                       [Drama, Comedy]  8.008307
# 9   [Adventure, Drama, Science Fiction]  8.007335
# 10                       [Drama, Crime]  7.997909
# 11             [Thriller, Crime, Drama]  7.963008
# 12                              [Drama]  7.961234
# 13              [Fantasy, Drama, Crime]  7.956465
# 14                       [Drama, Crime]  7.892657
